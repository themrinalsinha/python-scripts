# %% [markdown]
# ### Starting with WeasyPrint
#
# Installation:
# Source: https://weasyprint.readthedocs.io/en/stable/install.html#linux
# - Required packages for ubuntu machine
#
# `sudo apt-get install build-essential python3-dev python3-pip python3-setuptools python3-wheel python3-cffi libcairo2 libpango-1.0-0 libpangocairo-1.0-0 libgdk-pixbuf2.0-0 libffi-dev shared-mime-info`
#
# - Now install package using
#
# `pip install WeasyPrint`
#
# You can also run it as executable.
#
# `
# $ weasyprint --help
# $ weasyprint http://weasyprint.org ./weasyprint-website.pdf
# `
#
# You can also play with WeasyPrint Navigator and WeasyPrint Renderer.
#
# `
# $python -m weasyprint.tools.navigator
# $python -m weasyprint.tools.renderer
# `

# %%
import pandas as pd

# %%
data = pd.read_csv("sample_100.csv")
data.head()
# Out:
#         Cin                                   Name   Status  Class  Category  \
# 0  AAA-0001  HANDOO & HANDOO LEGAL CONSULTANTS LLP   Active    NaN       NaN
# 1  AAA-0005        JAIN & PARTNERS CONSULTANTS LLP   Active    NaN       NaN
# 2  AAA-0029                 CASCADE AUTOMATION LLP   Active    NaN       NaN
# 3  AAA-0030                  FORTIUS MARKETING LLP   Active    NaN       NaN
# 4  AAA-0048                TAC-TIC ADVERTISING LLP  Defunct    NaN       NaN
#
#    SubCategory IncorporationDate  State  AuthorizedCapital  PaidUpCapital  \
# 0          NaN        2009-04-02    NaN                0.0            0.0
# 1          NaN        2009-04-29    NaN                0.0            0.0
# 2          NaN        2009-06-05    NaN                0.0            0.0
# 3          NaN        2009-06-08    NaN                0.0            0.0
# 4          NaN        2009-06-24    NaN                0.0            0.0
#
#    ...  ForeignCompanyWithShareCapital  TotalObligation  \
# 0  ...                             NaN        1000000.0
# 1  ...                             NaN         100000.0
# 2  ...                             NaN          98000.0
# 3  ...                             NaN          10000.0
# 4  ...                             NaN         200000.0
#
#   MainDivisionOfBusiness TypeOfOffice  \
# 0                      0          NaN
# 1                     74          NaN
# 2                     72          NaN
# 3                     51          NaN
# 4                      0          NaN
#
#                            DescriptionOfMainDivision  \
# 0                                                NaN
# 1                          Other Business Activities
# 2                    Computer and related activities
# 3  Wholesale trade and commission trade, except o...
# 4                                                NaN
#
#                     FetchTime error_message  is_error  Pan  ActiveCompliance
# 0  2019-07-08 13:52:25.111846           NaN         0  NaN               NaN
# 1  2019-06-06 23:13:03.086385           NaN         0  NaN               NaN
# 2  2019-06-18 07:43:20.785526           NaN         0  NaN               NaN
# 3  2019-06-18 07:43:20.591206           NaN         0  NaN               NaN
# 4  2019-06-18 07:43:20.487958           NaN         0  NaN               NaN
#
# [5 rows x 35 columns]
